# %% [markdown]
# # **Import all the required libraries like pands for reading csv files and merging dataframe , numpy for mathmatical calculations ans os for I/O file trandfer**

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # **Reading csv file**

# %%
df = pd.read_csv('/content/drive/MyDrive/obdusingcsv/objects.csv')
df.head()
# Out:
#             id           center  class  subclass  \
# 0    001_1.jpg    899.50 755.00  Tiger       NaN
# 1  002_758.jpg   1340.00 830.00  Tiger       NaN
# 2   002_76.jpg  2593.50 1531.50  Tiger       NaN
# 3  002_761.jpg    324.50 799.00  Tiger       NaN
# 4  002_762.jpg    570.50 779.50  Tiger       NaN
#
#                              bbox  convex  headtail  orient  relevance  \
# 0   148.00 406.00 1651.00 1104.00     NaN       NaN     NaN          0
# 1   730.00 524.00 1950.00 1136.00     NaN       NaN     NaN          0
# 2  1928.00 850.00 3259.00 2213.00     NaN       NaN     NaN          0
# 3      1.00 582.00 648.00 1016.00     NaN       NaN     NaN          0
# 4    138.00 564.00 1003.00 995.00     NaN       NaN     NaN          0
#
#   mark_tool
# 0      BBox
# 1      BBox
# 2      BBox
# 3      BBox
# 4      BBox

# %% [markdown]
# # **Displaying shape of the dataset**

# %%
df.shape
# Out:
# (3537, 10)

# %% [markdown]
# # **Finding more information regarding datatypes of the coulumns in the dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3537 entries, 0 to 3536
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3537 non-null   object
#  1   center     3537 non-null   object
#  2   class      3537 non-null   object
#  3   subclass   0 non-null      float64
#  4   bbox       3537 non-null   object
#  5   convex     0 non-null      float64
#  6   headtail   0 non-null      float64
#  7   orient     0 non-null      float64
#  8   relevance  3537 non-null   int64
#  9   mark_tool  3537 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 276.5+ KB

# %% [markdown]
# # **Displaying any null values in the dataset**

# %%
df.isnull().sum()
# Out:
# id              0
# center          0
# class           0
# subclass     3537
# bbox            0
# convex       3537
# headtail     3537
# orient       3537
# relevance       0
# mark_tool       0
# dtype: int64

# %% [markdown]
# # **Dropping all the irrelevent columns with null values and unusefull data**

# %%
df.drop(['subclass' , 'convex' , 'headtail' , 'orient' , 'relevance'] , axis = 1 , inplace = True)

# %% [markdown]
# # **Displaying dataframe after removing columns**

# %%
df.head()
# Out:
#             id           center  class                            bbox  \
# 0    001_1.jpg    899.50 755.00  Tiger   148.00 406.00 1651.00 1104.00
# 1  002_758.jpg   1340.00 830.00  Tiger   730.00 524.00 1950.00 1136.00
# 2   002_76.jpg  2593.50 1531.50  Tiger  1928.00 850.00 3259.00 2213.00
# 3  002_761.jpg    324.50 799.00  Tiger      1.00 582.00 648.00 1016.00
# 4  002_762.jpg    570.50 779.50  Tiger    138.00 564.00 1003.00 995.00
#
#   mark_tool
# 0      BBox
# 1      BBox
# 2      BBox
# 3      BBox
# 4      BBox

# %% [markdown]
# # **Displaying number of remaining columns**

# %%
df.columns
# Out:
# Index(['id', 'center', 'class', 'bbox', 'mark_tool'], dtype='object')

# %% [markdown]
# # **Splitting the bbox column and concatinating into the dataframe**

# %%
df = pd.concat([df , df['bbox'].str.split(expand = True)] , axis = 1)

# %% [markdown]
# # **renaming the bbox columnd after split and concatination**

# %%
df_renamed = df.rename(columns = {0 : 'xmin', 1 : 'xmax' , 2 : 'ymin' , 3 : 'ymax'} , inplace = True)

# %% [markdown]
# # **Splitting the center column and concatinating into the dataframe**

# %%
df = pd.concat([df ,  df['center'].str.split(expand = True)] , axis = 1)

# %% [markdown]
# # **renaming the center columnd after split and concatination**

# %%
df_remaned_renamed = df.rename(columns = { 0 : 'center_width' , 1 : 'center_height'} , inplace = True)

# %%
df.head()
# Out:
#             id           center  class                            bbox  \
# 0    001_1.jpg    899.50 755.00  Tiger   148.00 406.00 1651.00 1104.00
# 1  002_758.jpg   1340.00 830.00  Tiger   730.00 524.00 1950.00 1136.00
# 2   002_76.jpg  2593.50 1531.50  Tiger  1928.00 850.00 3259.00 2213.00
# 3  002_761.jpg    324.50 799.00  Tiger      1.00 582.00 648.00 1016.00
# 4  002_762.jpg    570.50 779.50  Tiger    138.00 564.00 1003.00 995.00
#
#   mark_tool     xmin    xmax     ymin     ymax center_width center_height
# 0      BBox   148.00  406.00  1651.00  1104.00       899.50        755.00
# 1      BBox   730.00  524.00  1950.00  1136.00      1340.00        830.00
# 2      BBox  1928.00  850.00  3259.00  2213.00      2593.50       1531.50
# 3      BBox     1.00  582.00   648.00  1016.00       324.50        799.00
# 4      BBox   138.00  564.00  1003.00   995.00       570.50        779.50

# %% [markdown]
# # **Dropping old bbox and center columns**

# %%
df.drop(['center' , 'bbox'] , axis = 1 , inplace = True)

# %% [markdown]
# # **Displaying dataframe after preprocessing dataset**

# %%
df.head()
# Out:
#             id  class mark_tool     xmin    xmax     ymin     ymax  \
# 0    001_1.jpg  Tiger      BBox   148.00  406.00  1651.00  1104.00
# 1  002_758.jpg  Tiger      BBox   730.00  524.00  1950.00  1136.00
# 2   002_76.jpg  Tiger      BBox  1928.00  850.00  3259.00  2213.00
# 3  002_761.jpg  Tiger      BBox     1.00  582.00   648.00  1016.00
# 4  002_762.jpg  Tiger      BBox   138.00  564.00  1003.00   995.00
#
#   center_width center_height
# 0       899.50        755.00
# 1      1340.00        830.00
# 2      2593.50       1531.50
# 3       324.50        799.00
# 4       570.50        779.50

# %% [markdown]
# # **Saving the preprocessed dataset into the new file**

# %%
df.to_csv('/content/drive/MyDrive/obdusingcsv/tigers_split' ,index = False)

# %% [markdown]
# # **reading the new preprocessed dataset saved**

# %%
df1 = pd.read_csv('/content/drive/MyDrive/obdusingcsv/tigers_split')

# %% [markdown]
# # **Displaying dataframe after preprocessing dataset**

# %%
df1.head()
# Out:
#             id  class mark_tool    xmin   xmax    ymin    ymax  center_width  \
# 0    001_1.jpg  Tiger      BBox   148.0  406.0  1651.0  1104.0         899.5
# 1  002_758.jpg  Tiger      BBox   730.0  524.0  1950.0  1136.0        1340.0
# 2   002_76.jpg  Tiger      BBox  1928.0  850.0  3259.0  2213.0        2593.5
# 3  002_761.jpg  Tiger      BBox     1.0  582.0   648.0  1016.0         324.5
# 4  002_762.jpg  Tiger      BBox   138.0  564.0  1003.0   995.0         570.5
#
#    center_height
# 0          755.0
# 1          830.0
# 2         1531.5
# 3          799.0
# 4          779.5

# %% [markdown]
# # **Using bounding box formulae to conver pixel size to bounding box format of 0 and 1**

# %%
df1['xmin'] = df1['xmin'] / df1['center_width']
df1['xmax'] = df1['xmin'] / df1['center_height']
df1['ymin'] = df1['xmin'] / df1['center_width']
df1['ymax'] = df1['xmin'] / df1['center_height']

# %% [markdown]
# # **Displaying dataframe after calculating**

# %%
df1.head()
# Out:
#             id  class mark_tool      xmin      xmax      ymin      ymax  \
# 0    001_1.jpg  Tiger      BBox  0.164536  0.000218  0.000183  0.000218
# 1  002_758.jpg  Tiger      BBox  0.544776  0.000656  0.000407  0.000656
# 2   002_76.jpg  Tiger      BBox  0.743397  0.000485  0.000287  0.000485
# 3  002_761.jpg  Tiger      BBox  0.003082  0.000004  0.000009  0.000004
# 4  002_762.jpg  Tiger      BBox  0.241893  0.000310  0.000424  0.000310
#
#    center_width  center_height
# 0         899.5          755.0
# 1        1340.0          830.0
# 2        2593.5         1531.5
# 3         324.5          799.0
# 4         570.5          779.5

# %% [markdown]
# # **Droping the unwanted columns**

# %%
df1.drop(['mark_tool' , 'center_width' , 'center_height'] , axis = 1 , inplace = True)

# %% [markdown]
# # **Displaying final dataset**

# %%
df1.head()
# Out:
#             id  class      xmin      xmax      ymin      ymax
# 0    001_1.jpg  Tiger  0.164536  0.000218  0.000183  0.000218
# 1  002_758.jpg  Tiger  0.544776  0.000656  0.000407  0.000656
# 2   002_76.jpg  Tiger  0.743397  0.000485  0.000287  0.000485
# 3  002_761.jpg  Tiger  0.003082  0.000004  0.000009  0.000004
# 4  002_762.jpg  Tiger  0.241893  0.000310  0.000424  0.000310

# %% [markdown]
# # **writing loop to iterate the rows in the id coulumn and each file with seperate file name of each row and saving calculated bounding box information with class in a specified location**

# %%
for index , row in df1.iterrows() :
  file_name = "/content/drive/MyDrive/obdusingcsv/tigers labels/"+row['id'].split(".")[0]+".txt"
  with open (file_name , 'w') as file :

    mystr = '0 ' + str(row['xmin']) + ' ' + str(row['xmax']) + ' ' + str(row['ymin']) + ' ' + str(row['ymax'])
    file.write(mystr)
    print(row['id'])
# Out:
# 001_1.jpg
# 002_758.jpg
# 002_76.jpg
# 002_761.jpg
# 002_762.jpg
# 002_763.jpg
# 002_764.jpg
# 002_765.jpg
# 002_766.jpg
# 002_768.jpg
# 002_769.jpg
# 002_770.jpg
# 002_771.jpg
# 002_757.jpg
# 002_773.jpg
# 002_754.jpg
# 002_795.jpg
# 002_796.jpg
# 002_797.jpg
# 002_798.jpg
# 002_799.jpg
# 002_8.jpg
# 002_80.jpg
# 002_800.jpg
# 002_775.jpg
# 002_749.jpg
# 002_774.jpg
# 002_75.jpg
# 002_752.jpg
# 002_753.jpg
# 002_755.jpg
# 002_692.jpg
# 002_690.jpg
# 002_58.jpg
# 002_627.jpg
# 002_628.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-392-18857be9bb72> in <cell line: 1>()
#       1 for index , row in df1.iterrows() :
#       2   file_name = "/content/drive/MyDrive/obdusingcsv/tigers labels/"+row['id'].split(".")[0]+".txt"
# ----> 3   with open (file_name , 'w') as file :
#       4
# ...

# %%
#for index , row in df.iterrows() :
  #file_name = "/content/drive/MyDrive/Datasets/titanicdataset/annotated file/"+row['id'].split(".")[0]+".txt"
  #with open (file_name , 'w') as file :

    #mystr = '0 ' + row['bbox']
    #file.write(mystr)
    #print(row['id'])

# %%
df['id']
